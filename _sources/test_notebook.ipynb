# %% [markdown]
# # Test Notebook

# %% [markdown]
# <pre>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </pre>

# %% [markdown]
# (secfigcos)=
# ## Figcos

# %%
from myst_nb import glue
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 1000)
y = np.cos(x)**2
fig = plt.figure()
plt.plot(x,y)

glue("figcos", fig, display=False)
